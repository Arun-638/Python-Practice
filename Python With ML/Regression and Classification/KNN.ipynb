# %% [markdown]
# KNN Algorithm With Example

# %%
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, f1_score,recall_score

# %%
def euclidean_distance(point1, point2):
    return np.sqrt(np.sum((point1 - point2) ** 2))

# %%
def knn_predict(training_set,training_labels, test_point, k):
    distances = []
    for i in range(len(training_set)):
        distance = euclidean_distance(training_set[i],test_point)
        distances.append((distance, training_labels[i]))
    distances.sort(key=lambda x: x[0])
    k_nearest_neighbors = distances[:k]
    k_nearest_labels = [label for distance, label in k_nearest_neighbors]
    common = {}
    for label in k_nearest_labels:
        if label in common:
            common[label] += 1
        else:
            common[label] = 1
    return  max(common, key=common.get)

# %%
iris = load_iris()
X = iris.data
Y = iris.target
Y_pred = []
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.2, random_state = 42)
for test_point in X_test:
    predict = knn_predict(X_train, Y_train, test_point, k=3)
    Y_pred.append(predict)
accuracy = accuracy_score(Y_test, Y_pred)
precision = precision_score(Y_test, Y_pred, average='weighted')
f1 = f1_score(Y_test, Y_pred, average='weighted')
recall = recall_score(Y_test, Y_pred, average='weighted')
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"F1 Score: {f1:.4f}")
print(f"Recall: {recall:.4f}")
# Out:
# Accuracy: 1.0000
# Precision: 1.0000
# F1 Score: 1.0000
# Recall: 1.0000
